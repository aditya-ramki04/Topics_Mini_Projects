# %%
# !git clone https://github.com/cyneuro/CI-BioEng-Class.git
# %cd CI-BioEng-Class/fear_simulation
# Out:
# Cloning into 'CI-BioEng-Class'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 119 (delta 48), reused 57 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 7.12 MiB | 21.08 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation

# %%
# !pip install neuron bmtk
# Out:
# Requirement already satisfied: neuron in /usr/local/lib/python3.12/dist-packages (9.0.1)
# Requirement already satisfied: bmtk in /usr/local/lib/python3.12/dist-packages (1.1.4)
# Requirement already satisfied: find-libpython in /usr/local/lib/python3.12/dist-packages (from neuron) (0.5.0)
# Requirement already satisfied: numpy>=1.9.3 in /usr/local/lib/python3.12/dist-packages (from neuron) (2.0.2)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.12/dist-packages (from neuron) (25.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from neuron) (75.2.0)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from neuron) (1.14.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from bmtk) (4.26.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from bmtk) (2.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from bmtk) (1.17.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from bmtk) (3.15.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bmtk) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from bmtk) (1.16.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from bmtk) (0.25.2)
# Requirement already satisfied: pynrrd in /usr/local/lib/python3.12/dist-packages (from bmtk) (1.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->neuron) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->bmtk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->bmtk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->bmtk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->bmtk) (0.30.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bmtk) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bmtk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bmtk) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bmtk) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bmtk) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bmtk) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bmtk) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->bmtk) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->bmtk) (2025.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from pynrrd->bmtk) (4.15.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->bmtk) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->bmtk) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->bmtk) (2026.1.14)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->bmtk) (0.4)

# %%
# %cd components/mechanisms
# !nrnivmodl .
# %cd ../../
# Out:
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms
# cfiles =
# Mod files: "./gap.mod" "./k_rtm.mod" "./k_wb.mod" "./leak.mod" "./na_rtm.mod" "./na_wb.mod" "./vecevent.mod"
#
# Creating 'x86_64' directory for .o files.
#
# MODOBJS= ./gap.o ./k_rtm.o ./k_wb.o ./leak.o ./na_rtm.o ./na_wb.o ./vecevent.o
#  -> Compiling mod_func.cpp
#  -> NMODL .././gap.mod
#  -> NMODL .././k_rtm.mod
#  -> NMODL .././k_wb.mod
# Translating k_wb.mod into /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/k_wb.cpp
# Thread Safe
#  -> NMODL .././leak.mod
# Translating gap.mod into /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/gap.cpp
# Thread Safe
#  -> NMODL .././na_rtm.mod
# Translating leak.mod into /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/leak.cpp
# Translating k_rtm.mod into /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/k_rtm.cpp
# Thread Safe
# Thread Safe
#  -> NMODL .././na_wb.mod
# Translating na_rtm.mod into /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/na_rtm.cpp
# Thread Safe
#  -> NMODL .././vecevent.mod
# Translating vecevent.mod into /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp
# Translating na_wb.mod into /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/na_wb.cpp
# Notice: ARTIFICIAL_CELL is a synonym for POINT_PROCESS which hints that it
# only affects and is affected by discrete events. As such it is not
# located in a section and is not associated with an integrator
# Thread Safe
# Thread Safe
#  -> Compiling /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/gap.cpp
#  -> Compiling /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/k_rtm.cpp
#  -> Compiling /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/k_wb.cpp
#  -> Compiling /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/leak.cpp
#  -> Compiling /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/na_rtm.cpp
#  -> Compiling /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/na_wb.cpp
#  -> Compiling /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp: In function ‘int element__VecStim({anonymous}::_nrn_mechanism_cache_range*, size_t, Datum*, Datum*, double*, NrnThread*)’:
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:284:47: warning: ‘int vector_capacity(void*)’ is deprecated: non-void* overloads are preferred [-Wdeprecated-declarations]
#   284 |                         size = vector_capacity(vv);
#       |                                ~~~~~~~~~~~~~~~^~~~
# In file included from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/nrncvode.h:2,
#                  from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/mech_api.h:14,
#                  from /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:7:
# /usr/local/lib/python3.12/dist-packages/neuron/.data/include/oc_ansi.h:126:57: note: declared here
#   126 | [[deprecated("non-void* overloads are preferred")]] int vector_capacity(void*);
#       |                                                         ^~~~~~~~~~~~~~~
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:285:40: warning: ‘double* vector_vec(void*)’ is deprecated: non-void* overloads are preferred [-Wdeprecated-declarations]
#   285 |                         px = vector_vec(vv);
#       |                              ~~~~~~~~~~^~~~
# In file included from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/nrncvode.h:2,
#                  from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/mech_api.h:14,
#                  from /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:7:
# /usr/local/lib/python3.12/dist-packages/neuron/.data/include/oc_ansi.h:129:61: note: declared here
#   129 | [[deprecated("non-void* overloads are preferred")]] double* vector_vec(void*);
#       |                                                             ^~~~~~~~~~
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp: In function ‘int play__VecStim({anonymous}::_nrn_mechanism_cache_range*, size_t, Datum*, Datum*, double*, NrnThread*)’:
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:329:41: warning: ‘Object** vector_pobj(void*)’ is deprecated: non-void* overloads are preferred [-Wdeprecated-declarations]
#   329 |                 hoc_obj_ref(*vector_pobj(ptmp));
#       |                              ~~~~~~~~~~~^~~~~~
# In file included from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/nrncvode.h:2,
#                  from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/mech_api.h:14,
#                  from /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:7:
# /usr/local/lib/python3.12/dist-packages/neuron/.data/include/oc_ansi.h:127:62: note: declared here
#   127 | [[deprecated("non-void* overloads are preferred")]] Object** vector_pobj(void*);
#       |                                                              ^~~~~~~~~~~
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:333:43: warning: ‘Object** vector_pobj(void*)’ is deprecated: non-void* overloads are preferred [-Wdeprecated-declarations]
#   333 |                 hoc_obj_unref(*vector_pobj(*pv));
#       |                                ~~~~~~~~~~~^~~~~
# In file included from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/nrncvode.h:2,
#                  from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/mech_api.h:14,
#                  from /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:7:
# /usr/local/lib/python3.12/dist-packages/neuron/.data/include/oc_ansi.h:127:62: note: declared here
#   127 | [[deprecated("non-void* overloads are preferred")]] Object** vector_pobj(void*);
#       |                                                              ^~~~~~~~~~~
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp: In function ‘void bbcore_write(double*, int*, int*, int*, Memb_list*, size_t, Datum*, Datum*, double*, NrnThread*)’:
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:367:28: warning: ‘int vector_capacity(void*)’ is deprecated: non-void* overloads are preferred [-Wdeprecated-declarations]
#   367 |     dsize = vector_capacity(_p_ptr);
#       |             ~~~~~~~~~~~~~~~^~~~~~~~
# In file included from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/nrncvode.h:2,
#                  from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/mech_api.h:14,
#                  from /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:7:
# /usr/local/lib/python3.12/dist-packages/neuron/.data/include/oc_ansi.h:126:57: note: declared here
#   126 | [[deprecated("non-void* overloads are preferred")]] int vector_capacity(void*);
#       |                                                         ^~~~~~~~~~~~~~~
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:375:22: warning: ‘double* vector_vec(void*)’ is deprecated: non-void* overloads are preferred [-Wdeprecated-declarations]
#   375 |       dv = vector_vec(vec);
#       |            ~~~~~~~~~~^~~~~
# In file included from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/nrncvode.h:2,
#                  from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/mech_api.h:14,
#                  from /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:7:
# /usr/local/lib/python3.12/dist-packages/neuron/.data/include/oc_ansi.h:129:61: note: declared here
#   129 | [[deprecated("non-void* overloads are preferred")]] double* vector_vec(void*);
#       |                                                             ^~~~~~~~~~
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp: In function ‘void bbcore_read(double*, int*, int*, int*, Memb_list*, size_t, Datum*, Datum*, double*, NrnThread*)’:
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:393:18: warning: ‘double* vector_vec(void*)’ is deprecated: non-void* overloads are preferred [-Wdeprecated-declarations]
#   393 |   dv = vector_vec(_p_ptr);
#       |        ~~~~~~~~~~^~~~~~~~
# In file included from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/nrncvode.h:2,
#                  from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/mech_api.h:14,
#                  from /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:7:
# /usr/local/lib/python3.12/dist-packages/neuron/.data/include/oc_ansi.h:129:61: note: declared here
#   129 | [[deprecated("non-void* overloads are preferred")]] double* vector_vec(void*);
#       |                                                             ^~~~~~~~~~
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp: In function ‘void _destructor(Prop*)’:
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:413:43: warning: ‘Object** vector_pobj(void*)’ is deprecated: non-void* overloads are preferred [-Wdeprecated-declarations]
#   413 |                 hoc_obj_unref(*vector_pobj(vv));
#       |                                ~~~~~~~~~~~^~~~
# In file included from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/nrncvode.h:2,
#                  from /usr/local/lib/python3.12/dist-packages/neuron/.data/include/mech_api.h:14,
#                  from /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/vecevent.cpp:7:
# /usr/local/lib/python3.12/dist-packages/neuron/.data/include/oc_ansi.h:127:62: note: declared here
#   127 | [[deprecated("non-void* overloads are preferred")]] Object** vector_pobj(void*);
#       |                                                              ^~~~~~~~~~~
#  => LINKING shared library "/content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/./libnrnmech.so"
#  => LINKING executable "/content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/components/mechanisms/x86_64/./special" LDFLAGS are:
# Successfully created x86_64/special
# /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation

# %%
# !python build_network.py
# !python update_configs.py
# !python run_bionet.py config.json
# !python check_output.py
# Out:
# WARNING:root:Configuration file /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/config.json already exists, skipping. Please delete existing file, use a different name, or use overwrite_config=True.
# WARNING:root:Configuration file /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/circuit_config.json already exists, skipping. Please delete existing file, use a different name, or use overwrite_config=True.
# WARNING:root:Configuration file /content/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/CI-BioEng-Class/fear_simulation/simulation_config.json already exists, skipping. Please delete existing file, use a different name, or use overwrite_config=True.
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
# 2026-01-29 22:40:20,032 [INFO] Created log file
# 2026-01-29 22:40:20,107 [INFO] Building cells.
# 2026-01-29 22:40:20,214 [INFO] Building recurrent connections
# 2026-01-29 22:40:20,759 [INFO] Running simulation for 1000.000 ms with the time step 0.100 ms
# 2026-01-29 22:40:20,760 [INFO] Starting timestep: 0 at t_sim: 0.000 ms
# 2026-01-29 22:40:20,760 [INFO] Block save every 5000 steps
# 2026-01-29 22:40:26,988 [INFO]     step:5000 t_sim:500.00 ms
# 2026-01-29 22:40:32,470 [INFO]     step:10000 t_sim:1000.00 ms
# 2026-01-29 22:40:32,489 [INFO] Simulation completed in 11.73 seconds
# The network is oscillating around 3.917727717925015 Hz.
# sh: 1: uflash: not found

# %%
# !grep I_E parameters.py
# Out:
#     I_E = 0.2; # I_I = 0.0
